# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. **Подготовка к работе**

# %%
import pandas as pd
import numpy as np
songs = pd.read_csv('/home/plokmit/csv/spotify-2023.csv', encoding='latin-1')

# %% [markdown]
# 2. **Просмотр информации**

# %%
songs.head(5)
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# Подсчёт количества строк в датафрейме

# %%
len(songs)
# Out:
# 953

# %% [markdown]
# Подсчет строк и столбцов

# %%
songs.shape
# Out:
# (953, 24)

# %% [markdown]
# Получение n записей из начала или конца датафрейма

# %%
songs.head(3)
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# ...

# %%
songs.tail(1)
# Out:
#     track_name artist(s)_name  artist_count  released_year  released_month  \
# 952      Alone      Burna Boy             1           2022              11
#
#      released_day  in_spotify_playlists  in_spotify_charts   streams  \
# 952             4                   782                  2  96007391
#
#      in_apple_playlists  ...  bpm key   mode danceability_%  valence_%  \
# 952                  27  ...   90   E  Minor             61         32
#
#     energy_% acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 952       67             15                   0          11              5
#
# [1 rows x 24 columns]

# %% [markdown]
# Подсчет уникальных значений в столбце

# %%
len(songs['released_year'].unique())
# Out:
# 50

# %% [markdown]
# Вывод статистических сведений о датафрейме
#
# Знание статистических сведений о датафрейме весьма полезно в ситуациях,
# когда он содержит множество числовых значений.
# Например, знание среднего, минимального и максимального значений столбца rating
# даёт нам некоторое понимание того, как, в целом, выглядит датафрейм.
# Вот соответствующая команда:

# %%
songs.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
#  **Извлечение информации из датафреймов**

# %% [markdown]
# Создание списка или объекта Series на основе значений столбца

# %%
songs['artist(s)_name'].tolist()
# Out:
# ['Latto, Jung Kook',
#  'Myke Towers',
#  'Olivia Rodrigo',
#  'Taylor Swift',
#  'Bad Bunny',
#  'Dave, Central Cee',
#  'Eslabon Armado, Peso Pluma',
#  'Quevedo',
#  'Gunna',
#  'Peso Pluma, Yng Lvcas',
#  'Bad Bunny, Grupo Frontera',
#  'NewJeans',
#  'Miley Cyrus',
#  'David Kushner',
#  'Harry Styles',
#  'SZA',
#  'Fifty Fifty',
#  'Billie Eilish',
#  'Feid, Young Miko',
#  'Jimin',
#  'Gabito Ballesteros, Junior H, Peso Pluma',
#  'Taylor Swift',
#  'Arctic Monkeys',
#  'Bizarrap, Peso Pluma',
#  'The Weeknd, Madonna, Playboi Carti',
#  'Fuerza Regida',
#  'Rï¿½ï¿½ma, Selena G',
#  'Tainy, Bad Bunny',
#  'Morgan Wallen',
#  'Dua Lipa',
#  'Troye Sivan',
#  'Peso Pluma, Grupo Frontera',
#  'The Weeknd, 21 Savage, Metro Boomin',
#  'Taylor Swift',
#  'Karol G, Shakira',
#  'Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk',
#  'Yahritza Y Su Esencia, Grupo Frontera',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Fuerza Regida',
# ...

# %% [markdown]
# Получение списка значений из индекса
# Если использовать songs.set_index, то индексы изменятся на значения любого столбца

# %%
songs_modified = songs.set_index('artist(s)_name')
songs_modified.index.tolist()
# Out:
# ['Latto, Jung Kook',
#  'Myke Towers',
#  'Olivia Rodrigo',
#  'Taylor Swift',
#  'Bad Bunny',
#  'Dave, Central Cee',
#  'Eslabon Armado, Peso Pluma',
#  'Quevedo',
#  'Gunna',
#  'Peso Pluma, Yng Lvcas',
#  'Bad Bunny, Grupo Frontera',
#  'NewJeans',
#  'Miley Cyrus',
#  'David Kushner',
#  'Harry Styles',
#  'SZA',
#  'Fifty Fifty',
#  'Billie Eilish',
#  'Feid, Young Miko',
#  'Jimin',
#  'Gabito Ballesteros, Junior H, Peso Pluma',
#  'Taylor Swift',
#  'Arctic Monkeys',
#  'Bizarrap, Peso Pluma',
#  'The Weeknd, Madonna, Playboi Carti',
#  'Fuerza Regida',
#  'Rï¿½ï¿½ma, Selena G',
#  'Tainy, Bad Bunny',
#  'Morgan Wallen',
#  'Dua Lipa',
#  'Troye Sivan',
#  'Peso Pluma, Grupo Frontera',
#  'The Weeknd, 21 Savage, Metro Boomin',
#  'Taylor Swift',
#  'Karol G, Shakira',
#  'Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk',
#  'Yahritza Y Su Esencia, Grupo Frontera',
#  'Taylor Swift',
#  'Taylor Swift',
#  'Fuerza Regida',
# ...

# %% [markdown]
# Получение списка значений столбцов

# %%
songs.columns.tolist()
# Out:
# ['track_name',
#  'artist(s)_name',
#  'artist_count',
#  'released_year',
#  'released_month',
#  'released_day',
#  'in_spotify_playlists',
#  'in_spotify_charts',
#  'streams',
#  'in_apple_playlists',
#  'in_apple_charts',
#  'in_deezer_playlists',
#  'in_deezer_charts',
#  'in_shazam_charts',
#  'bpm',
#  'key',
#  'mode',
#  'danceability_%',
#  'valence_%',
#  'energy_%',
#  'acousticness_%',
#  'instrumentalness_%',
#  'liveness_%',
#  'speechiness_%']

# %% [markdown]
# Посчитать количество вхождений строкового значения

# %%
songs['artist(s)_name'].value_counts()
# Out:
# artist(s)_name
# Taylor Swift                          34
# The Weeknd                            22
# Bad Bunny                             19
# SZA                                   19
# Harry Styles                          17
#                                       ..
# Gorillaz, Bad Bunny                    1
# j-hope, J. Cole                        1
# Robin Schulz, Oliver Tree              1
# Don Toliver, Future, Justin Bieber     1
# The Walters                            1
# Name: count, Length: 645, dtype: int64

# %% [markdown]
# Добавить новый столбец

# %%
songs['train set'] = True

# %%
Создание нового датафрейма из подмножества столбцов

Это может пригодиться в том случае, если требуется сохранить 
в новом датафрейме несколько столбцов огромного датафрейма, 
но при этом не хочется выписывать имена столбцов, которые нужно удалить.
# Out:
#   Cell In[27], line 1
#     Создание нового датафрейма из подмножества столбцов
#              ^
# SyntaxError: invalid syntax

# %%
songs[['track_name', 'artist(s)_name']].head(3)
# Out:
#                             track_name    artist(s)_name
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook
# 1                                 LALA       Myke Towers
# 2                              vampire    Olivia Rodrigo

# %% [markdown]
# Удалить столбцы

# %%
songs.drop(['track_name', 'artist(s)_name'], axis=1).head()
# Out:
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
#
#    in_spotify_playlists  in_spotify_charts    streams  in_apple_playlists  \
# 0                   553                147  141381703                  43
# 1                  1474                 48  133716286                  48
# 2                  1397                113  140003974                  94
# 3                  7858                100  800840817                 116
# 4                  3133                 50  303236322                  84
#
#    in_apple_charts in_deezer_playlists  ...  key   mode  danceability_%  \
# 0              263                  45  ...    B  Major              80
# ...

# %% [markdown]
# Посчитать сумму стобцов

# %%
songs.loc['Total']= songs.sum(numeric_only=True)

# %%
songs.tail(2)
# Out:
#       track_name artist(s)_name  artist_count  released_year  released_month  \
# 952        Alone      Burna Boy           1.0         2022.0            11.0
# Total        NaN            NaN        1483.0      1923381.0          5750.0
#
#        released_day  in_spotify_playlists  in_spotify_charts   streams  \
# 952             4.0                 782.0                2.0  96007391
# Total       13276.0             4955719.0            11445.0       NaN
#
#        in_apple_playlists  ...  key   mode  danceability_% valence_%  \
# 952                  27.0  ...    E  Minor            61.0      32.0
# Total             64625.0  ...  NaN    NaN         63822.0   49014.0
#
#        energy_% acousticness_% instrumentalness_%  liveness_%  speechiness_%  \
# 952        67.0           15.0                0.0        11.0            5.0
# Total   61258.0        25786.0             1507.0     17357.0         9655.0
#
#        train set
# 952          1.0
# Total      953.0
#
# ...

# %% [markdown]
# Сумму строк:

# %%
songs['Total_sum'] = songs.sum(numeric_only=True, axis=1)
songs.tail(4)
# Out:
#                  track_name      artist(s)_name  artist_count  released_year  \
# 950    A Veces (feat. Feid)  Feid, Paulo Londra           2.0         2022.0
# 951           En La De Ella  Feid, Sech, Jhayco           3.0         2022.0
# 952                   Alone           Burna Boy           1.0         2022.0
# Total                   NaN                 NaN        1483.0      1923381.0
#
#        released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 950              11.0           3.0                 573.0                0.0
# 951              10.0          20.0                1320.0                0.0
# 952              11.0           4.0                 782.0                2.0
# Total          5750.0       13276.0             4955719.0            11445.0
#
#          streams  in_apple_playlists  ...   mode danceability_%  valence_%  \
# 950     73513683                 2.0  ...  Major           80.0       81.0
# ...

# %% [markdown]
# *Конкатенация двух датафреймов*
#
# Эта методика применима в ситуациях, когда имеются два датафрейма с одинаковыми столбцами, которые нужно скомбинировать.
#
# В данном примере мы сначала разделяем датафрейм на две части, а потом снова объединяем эти части:

# %% [markdown]
# **Корреляция**

# %%
songs.corr(numeric_only=True)
# Out:
#                       artist_count  released_year  released_month  \
# artist_count              1.000000       0.999827        0.999657
# released_year             0.999827       1.000000        0.999817
# released_month            0.999657       0.999817        1.000000
# released_day              0.999591       0.999771        0.999620
# in_spotify_playlists      0.998523       0.998786        0.998507
# in_spotify_charts         0.998415       0.998607        0.998374
# in_apple_playlists        0.998935       0.999145        0.998963
# in_apple_charts           0.999275       0.999500        0.999305
# in_deezer_charts          0.997139       0.997318        0.997126
# bpm                       0.999794       0.999972        0.999783
# danceability_%            0.999829       0.999975        0.999785
# valence_%                 0.999753       0.999890        0.999673
# energy_%                  0.999813       0.999965        0.999768
# ...

# %%
df1 = songs[0:2]
df2 = songs[2:]
pd.concat([df1, df2], ignore_index=True)
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook           2.0
# 1                                   LALA         Myke Towers           1.0
# 2                                vampire      Olivia Rodrigo           1.0
# 3                           Cruel Summer        Taylor Swift           1.0
# 4                         WHERE SHE GOES           Bad Bunny           1.0
# ..                                   ...                 ...           ...
# 949            Bigger Than The Whole Sky        Taylor Swift           1.0
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra           2.0
# 951                        En La De Ella  Feid, Sech, Jhayco           3.0
# 952                                Alone           Burna Boy           1.0
# 953                                  NaN                 NaN        1483.0
#
# ...

# %% [markdown]
# Фильтрация по значению
#
# Из датафреймов можно выбирать строки, соответствующие заданному условию. Обратите внимание на то, что при использовании этого метода сохраняются существующие индексные значения.

# %%
songs[songs['artist_count'] > 2]
# Out:
#                                               track_name  \
# 20                                             LADY GAGA
# 24     Popular (with Playboi Carti & Madonna) - The I...
# 32                                              Creepin'
# 35                                       Los del Espacio
# 43                                         See You Again
# ...                                                  ...
# 929                            Bamba (feat. Aitch & BIA)
# 930                                  Casei Com a Putaria
# 932                Pussy & Millions (feat. Travis Scott)
# 951                                        En La De Ella
# Total                                                NaN
#
#                                           artist(s)_name  artist_count  \
# 20              Gabito Ballesteros, Junior H, Peso Pluma           3.0
# 24                    The Weeknd, Madonna, Playboi Carti           3.0
# ...

# %% [markdown]
# Можем заменить значения столбца по условию на другие

# %%
songs_new = songs.copy()
songs_new.loc[songs['artist_count'] < 2, 'artist_count'] = 0
songs_new.head(3)
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook           2.0
# 1                                 LALA       Myke Towers           0.0
# 2                              vampire    Olivia Rodrigo           0.0
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0         2023.0             7.0          14.0                 553.0
# 1         2023.0             3.0          23.0                1474.0
# 2         2023.0             6.0          30.0                1397.0
#
#    in_spotify_charts    streams  in_apple_playlists  ...   mode  \
# 0              147.0  141381703                43.0  ...  Major
# 1               48.0  133716286                48.0  ...  Major
# 2              113.0  140003974                94.0  ...  Major
#
#   danceability_%  valence_% energy_%  acousticness_% instrumentalness_%  \
# ...

# %% [markdown]
# Сортировка
#
# Для сортировки датафреймов по значениям столбцов можно воспользоваться функцией df.sort_values:

# %%
songs.sort_values('artist_count', ascending=False)
# Out:
#                                               track_name  \
# Total                                                NaN
# 642                                             Se Le Ve
# 35                                       Los del Espacio
# 506                            We Don't Talk About Bruno
# 667    Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...
# ...                                                  ...
# 411                                  MIDDLE OF THE NIGHT
# 412                                             Atlantis
# 415                                 How Do I Say Goodbye
# 416                                                Blind
# 395                                           Space Song
#
#                                           artist(s)_name  artist_count  \
# Total                                                NaN        1483.0
# 642    Arcangel, De La Ghetto, Justin Quiles, Lenny T...           8.0
# ...

# %% [markdown]
# 10.**Агрегирование**
#
# ▍Функция df.groupby и подсчёт количества записей
#
# Вот как подсчитать количество записей с различными значениями в столбцах:
#
# anime.groupby('type').count()
#
#
#
# Результаты выполнения команды
#
# ▍Функция df.groupby и агрегирование столбцов различными способами
#
# Обратите внимание на то, что здесь используется reset_index(). В противном случае столбец type становится индексным столбцом. В большинстве случаев я рекомендую делать то же самое.
#
# anime.groupby(["type"]).agg({
#   "rating": "sum",
#   "episodes": "count",
#   "name": "last"
# }).reset_index()
#
# ▍Создание сводной таблицы
#
# Для того чтобы извлечь из датафрейма некие данные, нет ничего лучше, чем сводная таблица. Обратите внимание на то, что здесь я серьёзно отфильтровал датафрейм, что ускорило создание сводной таблицы.
#
# tmp_df = rating.copy()
# tmp_df.sort_values('user_id', ascending=True, inplace=True)
# tmp_df = tmp_df[tmp_df.user_id < 10]
# tmp_df = tmp_df[tmp_df.anime_id < 30]
# tmp_df = tmp_df[tmp_df.rating != -1]
# pd.pivot_table(tmp_df, values='rating', index=['user_id'], columns=['anime_id'], aggfunc=np.sum, fill_value=0)
#
#
#
# Результаты выполнения команды
#
# 11. Очистка данных
#
# ▍Запись в ячейки, содержащие значение NaN, какого-то другого значения
#
# Здесь мы поговорим о записи значения 0 в ячейки, содержащие значение NaN. В этом примере мы создаём такую же сводную таблицу, как и ранее, но без использования fill_value=0. А затем используем функцию fillna(0) для замены значений NaN на 0.
#
# pivot = pd.pivot_table(tmp_df, values='rating', index=['user_id'], columns=['anime_id'], aggfunc=np.sum)
# pivot.fillna(0)
#
#
#
# Таблица, содержащая значения NaN
#
#
#
# Результаты замены значений NaN на 0
#
# 12. Другие полезные возможности
#
# ▍Отбор случайных образцов из набора данных
#
# Я использую функцию df.sample каждый раз, когда мне нужно получить небольшой случайный набор строк из большого датафрейма. Если используется параметр frac=1, то функция позволяет получить аналог исходного датафрейма, строки которого будут перемешаны.
#
# anime.sample(frac=0.25)
#
#
#
# Результаты выполнения команды
#
# ▍Перебор строк датафрейма
#
# Следующая конструкция позволяет перебирать строки датафрейма:
#
# for idx,row in anime[:2].iterrows():
#     print(idx, row)
#
#
#
# Результаты выполнения команды
#
# ▍Борьба с ошибкой IOPub data rate exceeded
#
# Если вы сталкиваетесь с ошибкой IOPub data rate exceeded — попробуйте, при запуске Jupyter Notebook, воспользоваться следующей командой:
#
# jupyter notebook — NotebookApp.iopub_data_rate_limit=1.0e10
